# %%
import numpy as np
import pandas as pd
from matplotlib import font_manager, rc
import matplotlib
import seaborn as sns
import matplotlib.pyplot as plt

font_name = font_manager.FontProperties(fname="c:/Windows/Fonts/malgun.ttf").get_name()
rc('font', family=font_name)
matplotlib.rcParams['axes.unicode_minus'] = False

# %% [markdown]
# ## `Data load`

# %%
data = pd.read_csv("C:/Users/Moon/Desktop/Github/BigContest_Flood-ZERO/문우혁/Data_Before/train.csv")
data.head(3)
# Out:
#    홍수사상번호       연    월     일    시간         유입량  유역평균강수1  강우A1  ...     수위D5  유역평균강수6  강우A6  강우B6  강우C6  강우D6  수위E6    수위D6
# 0     1.0  2006.0  7.0  10.0   8.0  189.100000      6.4     7  ...  122.660      6.4     7     7     8     8  2.54  122.61
# 1     1.0  2006.0  7.0  10.0   9.0  216.951962      6.3     7  ...  122.648      7.3     7     8    10    10  2.53  122.60
# 2     1.0  2006.0  7.0  10.0  10.0  251.424419      6.4     7  ...  122.636      8.2     7     9    10    11  2.53  122.59
#
# [3 rows x 48 columns]

# %%
X = data.drop('유입량', axis=1)
y = data['유입량']

# %%
X.head(3)
# Out:
#    홍수사상번호       연    월     일    시간  유역평균강수1  강우A1  강우B1  ...     수위D5  유역평균강수6  강우A6  강우B6  강우C6  강우D6  수위E6    수위D6
# 0     1.0  2006.0  7.0  10.0   8.0      6.4     7     7  ...  122.660      6.4     7     7     8     8  2.54  122.61
# 1     1.0  2006.0  7.0  10.0   9.0      6.3     7     8  ...  122.648      7.3     7     8    10    10  2.53  122.60
# 2     1.0  2006.0  7.0  10.0  10.0      6.4     7     9  ...  122.636      8.2     7     9    10    11  2.53  122.59
#
# [3 rows x 47 columns]

# %%
X = X.drop(['홍수사상번호', '연', '일', '시간'], axis=1)

# %%
X.head(3)
# Out:
#      월  유역평균강수1  강우A1  강우B1  강우C1  강우D1  수위E1       수위D1  ...     수위D5  유역평균강수6  강우A6  강우B6  강우C6  강우D6  수위E6    수위D6
# 0  7.0      6.4     7     7     7     8  2.54  122.56875  ...  122.660      6.4     7     7     8     8  2.54  122.61
# 1  7.0      6.3     7     8     7     8  2.53  122.56250  ...  122.648      7.3     7     8    10    10  2.53  122.60
# 2  7.0      6.4     7     9     7     8  2.53  122.55625  ...  122.636      8.2     7     9    10    11  2.53  122.59
#
# [3 rows x 43 columns]

# %%
X_1_1 = X.drop(X.iloc[:, 8:], axis=1)
X_1_1 = X_1_1.iloc[:226]


X_1_2 = X.drop(X.iloc[:, 1:8], axis=1)
X_1_2 = X_1_2.drop(X.iloc[:, 15:], axis=1)
X_1_2 = X_1_2.iloc[:226]


X_1_3 = X.drop(X.iloc[:, 1:15], axis=1)
X_1_3 = X_1_3.drop(X.iloc[:, 22:], axis=1)
X_1_3 = X_1_3.iloc[:226]


X_1_4 = X.drop(X.iloc[:, 1:22], axis=1)
X_1_4 = X_1_4.drop(X.iloc[:, 29:], axis=1)
X_1_4 = X_1_4.iloc[:226]


X_1_5 = X.drop(X.iloc[:, 1:29], axis=1)
X_1_5 = X_1_5.drop(X.iloc[:, 36:], axis=1)
X_1_5 = X_1_5.iloc[:226]


X_1_6 = X.drop(X.iloc[:, 1:36], axis=1)
X_1_6 = X_1_6.drop(X.iloc[:, 43:], axis=1)
X_1_6 = X_1_6.iloc[:226]


X_2_1 = X.drop(X.iloc[:, 8:], axis=1)
X_2_1 = X_2_1.iloc[226:326]


X_2_2 = X.drop(X.iloc[:, 1:8], axis=1)
X_2_2 = X_2_2.drop(X.iloc[:, 15:], axis=1)
X_2_2 = X_2_2.iloc[226:326]


X_2_3 = X.drop(X.iloc[:, 1:15], axis=1)
X_2_3 = X_2_3.drop(X.iloc[:, 22:], axis=1)
X_2_3 = X_2_3.iloc[226:326]


X_2_4 = X.drop(X.iloc[:, 1:22], axis=1)
X_2_4 = X_2_4.drop(X.iloc[:, 29:], axis=1)
X_2_4 = X_2_4.iloc[226:326]


X_2_5 = X.drop(X.iloc[:, 1:29], axis=1)
X_2_5 = X_2_5.drop(X.iloc[:, 36:], axis=1)
X_2_5 = X_2_5.iloc[226:326]


X_2_6 = X.drop(X.iloc[:, 1:36], axis=1)
X_2_6 = X_2_6.drop(X.iloc[:, 43:], axis=1)
X_2_6 = X_2_6.iloc[226:326]


X_3_1 = X.drop(X.iloc[:, 8:], axis=1)
X_3_1 = X_3_1.iloc[326:407]


X_3_2 = X.drop(X.iloc[:, 1:8], axis=1)
X_3_2 = X_3_2.drop(X.iloc[:, 15:], axis=1)
X_3_2 = X_3_2.iloc[326:407]


X_3_3 = X.drop(X.iloc[:, 1:15], axis=1)
X_3_3 = X_3_3.drop(X.iloc[:, 22:], axis=1)
X_3_3 = X_3_3.iloc[326:407]


X_3_4 = X.drop(X.iloc[:, 1:22], axis=1)
X_3_4 = X_3_4.drop(X.iloc[:, 29:], axis=1)
X_3_4 = X_3_4.iloc[326:407]


X_3_5 = X.drop(X.iloc[:, 1:29], axis=1)
X_3_5 = X_3_5.drop(X.iloc[:, 36:], axis=1)
X_3_5 = X_3_5.iloc[326:407]


X_3_6 = X.drop(X.iloc[:, 1:36], axis=1)
X_3_6 = X_3_6.drop(X.iloc[:, 43:], axis=1)
X_3_6 = X_3_6.iloc[326:407]


X_4_1 = X.drop(X.iloc[:, 8:], axis=1)
X_4_1 = X_4_1.iloc[407:441]


X_4_2 = X.drop(X.iloc[:, 1:8], axis=1)
X_4_2 = X_4_2.drop(X.iloc[:, 15:], axis=1)
X_4_2 = X_4_2.iloc[407:441]


X_4_3 = X.drop(X.iloc[:, 1:15], axis=1)
X_4_3 = X_4_3.drop(X.iloc[:, 22:], axis=1)
X_4_3 = X_4_3.iloc[407:441]


X_4_4 = X.drop(X.iloc[:, 1:22], axis=1)
X_4_4 = X_4_4.drop(X.iloc[:, 29:], axis=1)
X_4_4 = X_4_4.iloc[407:441]


X_4_5 = X.drop(X.iloc[:, 1:29], axis=1)
X_4_5 = X_4_5.drop(X.iloc[:, 36:], axis=1)
X_4_5 = X_4_5.iloc[407:441]


X_4_6 = X.drop(X.iloc[:, 1:36], axis=1)
X_4_6 = X_4_6.drop(X.iloc[:, 43:], axis=1)
X_4_6 = X_4_6.iloc[407:441]


X_5_1 = X.drop(X.iloc[:, 8:], axis=1)
X_5_1 = X_5_1.iloc[441:535]


X_5_2 = X.drop(X.iloc[:, 1:8], axis=1)
X_5_2 = X_5_2.drop(X.iloc[:, 15:], axis=1)
X_5_2 = X_5_2.iloc[441:535]


X_5_3 = X.drop(X.iloc[:, 1:15], axis=1)
X_5_3 = X_5_3.drop(X.iloc[:, 22:], axis=1)
X_5_3 = X_5_3.iloc[441:535]


X_5_4 = X.drop(X.iloc[:, 1:22], axis=1)
X_5_4 = X_5_4.drop(X.iloc[:, 29:], axis=1)
X_5_4 = X_5_4.iloc[441:535]


X_5_5 = X.drop(X.iloc[:, 1:29], axis=1)
X_5_5 = X_5_5.drop(X.iloc[:, 36:], axis=1)
X_5_5 = X_5_5.iloc[441:535]


X_5_6 = X.drop(X.iloc[:, 1:36], axis=1)
X_5_6 = X_5_6.drop(X.iloc[:, 43:], axis=1)
X_5_6 = X_5_6.iloc[441:535]


X_6_1 = X.drop(X.iloc[:, 8:], axis=1)
X_6_1 = X_6_1.iloc[535:581]


X_6_2 = X.drop(X.iloc[:, 1:8], axis=1)
X_6_2 = X_6_2.drop(X.iloc[:, 15:], axis=1)
X_6_2 = X_6_2.iloc[535:581]


X_6_3 = X.drop(X.iloc[:, 1:15], axis=1)
X_6_3 = X_6_3.drop(X.iloc[:, 22:], axis=1)
X_6_3 = X_6_3.iloc[535:581]


X_6_4 = X.drop(X.iloc[:, 1:22], axis=1)
X_6_4 = X_6_4.drop(X.iloc[:, 29:], axis=1)
X_6_4 = X_6_4.iloc[535:581]


X_6_5 = X.drop(X.iloc[:, 1:29], axis=1)
X_6_5 = X_6_5.drop(X.iloc[:, 36:], axis=1)
X_6_5 = X_6_5.iloc[535:581]


X_6_6 = X.drop(X.iloc[:, 1:36], axis=1)
X_6_6 = X_6_6.drop(X.iloc[:, 43:], axis=1)
X_6_6 = X_6_6.iloc[535:581]


X_7_1 = X.drop(X.iloc[:, 8:], axis=1)
X_7_1 = X_7_1.iloc[581:632]


X_7_2 = X.drop(X.iloc[:, 1:8], axis=1)
X_7_2 = X_7_2.drop(X.iloc[:, 15:], axis=1)
X_7_2 = X_7_2.iloc[581:632]


X_7_3 = X.drop(X.iloc[:, 1:15], axis=1)
X_7_3 = X_7_3.drop(X.iloc[:, 22:], axis=1)
X_7_3 = X_7_3.iloc[581:632]


X_7_4 = X.drop(X.iloc[:, 1:22], axis=1)
X_7_4 = X_7_4.drop(X.iloc[:, 29:], axis=1)
X_7_4 = X_7_4.iloc[581:632]


X_7_5 = X.drop(X.iloc[:, 1:29], axis=1)
X_7_5 = X_7_5.drop(X.iloc[:, 36:], axis=1)
X_7_5 = X_7_5.iloc[581:632]


X_7_6 = X.drop(X.iloc[:, 1:36], axis=1)
X_7_6 = X_7_6.drop(X.iloc[:, 43:], axis=1)
X_7_6 = X_7_6.iloc[581:632]


X_8_1 = X.drop(X.iloc[:, 8:], axis=1)
X_8_1 = X_8_1.iloc[632:673]


X_8_2 = X.drop(X.iloc[:, 1:8], axis=1)
X_8_2 = X_8_2.drop(X.iloc[:, 15:], axis=1)
X_8_2 = X_8_2.iloc[632:673]


X_8_3 = X.drop(X.iloc[:, 1:15], axis=1)
X_8_3 = X_8_3.drop(X.iloc[:, 22:], axis=1)
X_8_3 = X_8_3.iloc[632:673]


X_8_4 = X.drop(X.iloc[:, 1:22], axis=1)
X_8_4 = X_8_4.drop(X.iloc[:, 29:], axis=1)
X_8_4 = X_8_4.iloc[632:673]


X_8_5 = X.drop(X.iloc[:, 1:29], axis=1)
X_8_5 = X_8_5.drop(X.iloc[:, 36:], axis=1)
X_8_5 = X_8_5.iloc[632:673]


X_8_6 = X.drop(X.iloc[:, 1:36], axis=1)
X_8_6 = X_8_6.drop(X.iloc[:, 43:], axis=1)
X_8_6 = X_8_6.iloc[632:673]


X_9_1 = X.drop(X.iloc[:, 8:], axis=1)
X_9_1 = X_9_1.iloc[673:741]


X_9_2 = X.drop(X.iloc[:, 1:8], axis=1)
X_9_2 = X_9_2.drop(X.iloc[:, 15:], axis=1)
X_9_2 = X_9_2.iloc[673:741]


X_9_3 = X.drop(X.iloc[:, 1:15], axis=1)
X_9_3 = X_9_3.drop(X.iloc[:, 22:], axis=1)
X_9_3 = X_9_3.iloc[673:741]


X_9_4 = X.drop(X.iloc[:, 1:22], axis=1)
X_9_4 = X_9_4.drop(X.iloc[:, 29:], axis=1)
X_9_4 = X_9_4.iloc[673:741]


X_9_5 = X.drop(X.iloc[:, 1:29], axis=1)
X_9_5 = X_9_5.drop(X.iloc[:, 36:], axis=1)
X_9_5 = X_9_5.iloc[673:741]


X_9_6 = X.drop(X.iloc[:, 1:36], axis=1)
X_9_6 = X_9_6.drop(X.iloc[:, 43:], axis=1)
X_9_6 = X_9_6.iloc[673:741]


X_10_1 = X.drop(X.iloc[:, 8:], axis=1)
X_10_1 = X_10_1.iloc[741:827]


X_10_2 = X.drop(X.iloc[:, 1:8], axis=1)
X_10_2 = X_10_2.drop(X.iloc[:, 15:], axis=1)
X_10_2 = X_10_2.iloc[741:827]


X_10_3 = X.drop(X.iloc[:, 1:15], axis=1)
X_10_3 = X_10_3.drop(X.iloc[:, 22:], axis=1)
X_10_3 = X_10_3.iloc[741:827]


X_10_4 = X.drop(X.iloc[:, 1:22], axis=1)
X_10_4 = X_10_4.drop(X.iloc[:, 29:], axis=1)
X_10_4 = X_10_4.iloc[741:827]


X_10_5 = X.drop(X.iloc[:, 1:29], axis=1)
X_10_5 = X_10_5.drop(X.iloc[:, 36:], axis=1)
X_10_5 = X_10_5.iloc[741:827]


X_10_6 = X.drop(X.iloc[:, 1:36], axis=1)
X_10_6 = X_10_6.drop(X.iloc[:, 43:], axis=1)
X_10_6 = X_10_6.iloc[741:827]


X_11_1 = X.drop(X.iloc[:, 8:], axis=1)
X_11_1 = X_11_1.iloc[827:937]


X_11_2 = X.drop(X.iloc[:, 1:8], axis=1)
X_11_2 = X_11_2.drop(X.iloc[:, 15:], axis=1)
X_11_2 = X_11_2.iloc[827:937]


X_11_3 = X.drop(X.iloc[:, 1:15], axis=1)
X_11_3 = X_11_3.drop(X.iloc[:, 22:], axis=1)
X_11_3 = X_11_3.iloc[827:937]


X_11_4 = X.drop(X.iloc[:, 1:22], axis=1)
X_11_4 = X_11_4.drop(X.iloc[:, 29:], axis=1)
X_11_4 = X_11_4.iloc[827:937]


X_11_5 = X.drop(X.iloc[:, 1:29], axis=1)
X_11_5 = X_11_5.drop(X.iloc[:, 36:], axis=1)
X_11_5 = X_11_5.iloc[827:937]


X_11_6 = X.drop(X.iloc[:, 1:36], axis=1)
X_11_6 = X_11_6.drop(X.iloc[:, 43:], axis=1)
X_11_6 = X_11_6.iloc[827:937]


X_12_1 = X.drop(X.iloc[:, 8:], axis=1)
X_12_1 = X_12_1.iloc[937:1064]


X_12_2 = X.drop(X.iloc[:, 1:8], axis=1)
X_12_2 = X_12_2.drop(X.iloc[:, 15:], axis=1)
X_12_2 = X_12_2.iloc[937:1064]


X_12_3 = X.drop(X.iloc[:, 1:15], axis=1)
X_12_3 = X_12_3.drop(X.iloc[:, 22:], axis=1)
X_12_3 = X_12_3.iloc[937:1064]


X_12_4 = X.drop(X.iloc[:, 1:22], axis=1)
X_12_4 = X_12_4.drop(X.iloc[:, 29:], axis=1)
X_12_4 = X_12_4.iloc[937:1064]


X_12_5 = X.drop(X.iloc[:, 1:29], axis=1)
X_12_5 = X_12_5.drop(X.iloc[:, 36:], axis=1)
X_12_5 = X_12_5.iloc[937:1064]


X_12_6 = X.drop(X.iloc[:, 1:36], axis=1)
X_12_6 = X_12_6.drop(X.iloc[:, 43:], axis=1)
X_12_6 = X_12_6.iloc[937:1064]


X_13_1 = X.drop(X.iloc[:, 8:], axis=1)
X_13_1 = X_13_1.iloc[1064:1131]


X_13_2 = X.drop(X.iloc[:, 1:8], axis=1)
X_13_2 = X_13_2.drop(X.iloc[:, 15:], axis=1)
X_13_2 = X_13_2.iloc[1064:1131]


X_13_3 = X.drop(X.iloc[:, 1:15], axis=1)
X_13_3 = X_13_3.drop(X.iloc[:, 22:], axis=1)
X_13_3 = X_13_3.iloc[1064:1131]


X_13_4 = X.drop(X.iloc[:, 1:22], axis=1)
X_13_4 = X_13_4.drop(X.iloc[:, 29:], axis=1)
X_13_4 = X_13_4.iloc[1064:1131]


X_13_5 = X.drop(X.iloc[:, 1:29], axis=1)
X_13_5 = X_13_5.drop(X.iloc[:, 36:], axis=1)
X_13_5 = X_13_5.iloc[1064:1131]


X_13_6 = X.drop(X.iloc[:, 1:36], axis=1)
X_13_6 = X_13_6.drop(X.iloc[:, 43:], axis=1)
X_13_6 = X_13_6.iloc[1064:1131]


X_14_1 = X.drop(X.iloc[:, 8:], axis=1)
X_14_1 = X_14_1.iloc[1131:1181]


X_14_2 = X.drop(X.iloc[:, 1:8], axis=1)
X_14_2 = X_14_2.drop(X.iloc[:, 15:], axis=1)
X_14_2 = X_14_2.iloc[1131:1181]


X_14_3 = X.drop(X.iloc[:, 1:15], axis=1)
X_14_3 = X_14_3.drop(X.iloc[:, 22:], axis=1)
X_14_3 = X_14_3.iloc[1131:1181]


X_14_4 = X.drop(X.iloc[:, 1:22], axis=1)
X_14_4 = X_14_4.drop(X.iloc[:, 29:], axis=1)
X_14_4 = X_14_4.iloc[1131:1181]


X_14_5 = X.drop(X.iloc[:, 1:29], axis=1)
X_14_5 = X_14_5.drop(X.iloc[:, 36:], axis=1)
X_14_5 = X_14_5.iloc[1131:1181]


X_14_6 = X.drop(X.iloc[:, 1:36], axis=1)
X_14_6 = X_14_6.drop(X.iloc[:, 43:], axis=1)
X_14_6 = X_14_6.iloc[1131:1181]


X_15_1 = X.drop(X.iloc[:, 8:], axis=1)
X_15_1 = X_15_1.iloc[1181:1443]


X_15_2 = X.drop(X.iloc[:, 1:8], axis=1)
X_15_2 = X_15_2.drop(X.iloc[:, 15:], axis=1)
X_15_2 = X_15_2.iloc[1181:1443]


X_15_3 = X.drop(X.iloc[:, 1:15], axis=1)
X_15_3 = X_15_3.drop(X.iloc[:, 22:], axis=1)
X_15_3 = X_15_3.iloc[1181:1443]


X_15_4 = X.drop(X.iloc[:, 1:22], axis=1)
X_15_4 = X_15_4.drop(X.iloc[:, 29:], axis=1)
X_15_4 = X_15_4.iloc[1181:1443]


X_15_5 = X.drop(X.iloc[:, 1:29], axis=1)
X_15_5 = X_15_5.drop(X.iloc[:, 36:], axis=1)
X_15_5 = X_15_5.iloc[1181:1443]


X_15_6 = X.drop(X.iloc[:, 1:36], axis=1)
X_15_6 = X_15_6.drop(X.iloc[:, 43:], axis=1)
X_15_6 = X_15_6.iloc[1181:1443]


X_16_1 = X.drop(X.iloc[:, 8:], axis=1)
X_16_1 = X_16_1.iloc[1443:1648]


X_16_2 = X.drop(X.iloc[:, 1:8], axis=1)
X_16_2 = X_16_2.drop(X.iloc[:, 15:], axis=1)
X_16_2 = X_16_2.iloc[1443:1648]


X_16_3 = X.drop(X.iloc[:, 1:15], axis=1)
X_16_3 = X_16_3.drop(X.iloc[:, 22:], axis=1)
X_16_3 = X_16_3.iloc[1443:1648]


X_16_4 = X.drop(X.iloc[:, 1:22], axis=1)
X_16_4 = X_16_4.drop(X.iloc[:, 29:], axis=1)
X_16_4 = X_16_4.iloc[1443:1648]


X_16_5 = X.drop(X.iloc[:, 1:29], axis=1)
X_16_5 = X_16_5.drop(X.iloc[:, 36:], axis=1)
X_16_5 = X_16_5.iloc[1443:1648]


X_16_6 = X.drop(X.iloc[:, 1:36], axis=1)
X_16_6 = X_16_6.drop(X.iloc[:, 43:], axis=1)
X_16_6 = X_16_6.iloc[1443:1648]


X_17_1 = X.drop(X.iloc[:, 8:], axis=1)
X_17_1 = X_17_1.iloc[1648:1773]


X_17_2 = X.drop(X.iloc[:, 1:8], axis=1)
X_17_2 = X_17_2.drop(X.iloc[:, 15:], axis=1)
X_17_2 = X_17_2.iloc[1648:1773]


X_17_3 = X.drop(X.iloc[:, 1:15], axis=1)
X_17_3 = X_17_3.drop(X.iloc[:, 22:], axis=1)
X_17_3 = X_17_3.iloc[1648:1773]


X_17_4 = X.drop(X.iloc[:, 1:22], axis=1)
X_17_4 = X_17_4.drop(X.iloc[:, 29:], axis=1)
X_17_4 = X_17_4.iloc[1648:1773]


X_17_5 = X.drop(X.iloc[:, 1:29], axis=1)
X_17_5 = X_17_5.drop(X.iloc[:, 36:], axis=1)
X_17_5 = X_17_5.iloc[1648:1773]


X_17_6 = X.drop(X.iloc[:, 1:36], axis=1)
X_17_6 = X_17_6.drop(X.iloc[:, 43:], axis=1)
X_17_6 = X_17_6.iloc[1648:1773]


X_18_1 = X.drop(X.iloc[:, 8:], axis=1)
X_18_1 = X_18_1.iloc[1773:1838]


X_18_2 = X.drop(X.iloc[:, 1:8], axis=1)
X_18_2 = X_18_2.drop(X.iloc[:, 15:], axis=1)
X_18_2 = X_18_2.iloc[1773:1838]


X_18_3 = X.drop(X.iloc[:, 1:15], axis=1)
X_18_3 = X_18_3.drop(X.iloc[:, 22:], axis=1)
X_18_3 = X_18_3.iloc[1773:1838]


X_18_4 = X.drop(X.iloc[:, 1:22], axis=1)
X_18_4 = X_18_4.drop(X.iloc[:, 29:], axis=1)
X_18_4 = X_18_4.iloc[1773:1838]


X_18_5 = X.drop(X.iloc[:, 1:29], axis=1)
X_18_5 = X_18_5.drop(X.iloc[:, 36:], axis=1)
X_18_5 = X_18_5.iloc[1773:1838]


X_18_6 = X.drop(X.iloc[:, 1:36], axis=1)
X_18_6 = X_18_6.drop(X.iloc[:, 43:], axis=1)
X_18_6 = X_18_6.iloc[1773:1838]


X_19_1 = X.drop(X.iloc[:, 8:], axis=1)
X_19_1 = X_19_1.iloc[1838:1933]


X_19_2 = X.drop(X.iloc[:, 1:8], axis=1)
X_19_2 = X_19_2.drop(X.iloc[:, 15:], axis=1)
X_19_2 = X_19_2.iloc[1838:1933]


X_19_3 = X.drop(X.iloc[:, 1:15], axis=1)
X_19_3 = X_19_3.drop(X.iloc[:, 22:], axis=1)
X_19_3 = X_19_3.iloc[1838:1933]


X_19_4 = X.drop(X.iloc[:, 1:22], axis=1)
X_19_4 = X_19_4.drop(X.iloc[:, 29:], axis=1)
X_19_4 = X_19_4.iloc[1838:1933]


X_19_5 = X.drop(X.iloc[:, 1:29], axis=1)
X_19_5 = X_19_5.drop(X.iloc[:, 36:], axis=1)
X_19_5 = X_19_5.iloc[1838:1933]


X_19_6 = X.drop(X.iloc[:, 1:36], axis=1)
X_19_6 = X_19_6.drop(X.iloc[:, 43:], axis=1)
X_19_6 = X_19_6.iloc[1838:1933]


X_20_1 = X.drop(X.iloc[:, 8:], axis=1)
X_20_1 = X_20_1.iloc[1933:2197]


X_20_2 = X.drop(X.iloc[:, 1:8], axis=1)
X_20_2 = X_20_2.drop(X.iloc[:, 15:], axis=1)
X_20_2 = X_20_2.iloc[1933:2197]


X_20_3 = X.drop(X.iloc[:, 1:15], axis=1)
X_20_3 = X_20_3.drop(X.iloc[:, 22:], axis=1)
X_20_3 = X_20_3.iloc[1933:2197]


X_20_4 = X.drop(X.iloc[:, 1:22], axis=1)
X_20_4 = X_20_4.drop(X.iloc[:, 29:], axis=1)
X_20_4 = X_20_4.iloc[1933:2197]


X_20_5 = X.drop(X.iloc[:, 1:29], axis=1)
X_20_5 = X_20_5.drop(X.iloc[:, 36:], axis=1)
X_20_5 = X_20_5.iloc[1933:2197]


X_20_6 = X.drop(X.iloc[:, 1:36], axis=1)
X_20_6 = X_20_6.drop(X.iloc[:, 43:], axis=1)
X_20_6 = X_20_6.iloc[1933:2197]


X_21_1 = X.drop(X.iloc[:, 8:], axis=1)
X_21_1 = X_21_1.iloc[2197:2281]


X_21_2 = X.drop(X.iloc[:, 1:8], axis=1)
X_21_2 = X_21_2.drop(X.iloc[:, 15:], axis=1)
X_21_2 = X_21_2.iloc[2197:2281]


X_21_3 = X.drop(X.iloc[:, 1:15], axis=1)
X_21_3 = X_21_3.drop(X.iloc[:, 22:], axis=1)
X_21_3 = X_21_3.iloc[2197:2281]


X_21_4 = X.drop(X.iloc[:, 1:22], axis=1)
X_21_4 = X_21_4.drop(X.iloc[:, 29:], axis=1)
X_21_4 = X_21_4.iloc[2197:2281]


X_21_5 = X.drop(X.iloc[:, 1:29], axis=1)
X_21_5 = X_21_5.drop(X.iloc[:, 36:], axis=1)
X_21_5 = X_21_5.iloc[2197:2281]


X_21_6 = X.drop(X.iloc[:, 1:36], axis=1)
X_21_6 = X_21_6.drop(X.iloc[:, 43:], axis=1)
X_21_6 = X_21_6.iloc[2197:2281]


X_22_1 = X.drop(X.iloc[:, 8:], axis=1)
X_22_1 = X_22_1.iloc[2281:2565]


X_22_2 = X.drop(X.iloc[:, 1:8], axis=1)
X_22_2 = X_22_2.drop(X.iloc[:, 15:], axis=1)
X_22_2 = X_22_2.iloc[2281:2565]


X_22_3 = X.drop(X.iloc[:, 1:15], axis=1)
X_22_3 = X_22_3.drop(X.iloc[:, 22:], axis=1)
X_22_3 = X_22_3.iloc[2281:2565]


X_22_4 = X.drop(X.iloc[:, 1:22], axis=1)
X_22_4 = X_22_4.drop(X.iloc[:, 29:], axis=1)
X_22_4 = X_22_4.iloc[2281:2565]


X_22_5 = X.drop(X.iloc[:, 1:29], axis=1)
X_22_5 = X_22_5.drop(X.iloc[:, 36:], axis=1)
X_22_5 = X_22_5.iloc[2281:2565]


X_22_6 = X.drop(X.iloc[:, 1:36], axis=1)
X_22_6 = X_22_6.drop(X.iloc[:, 43:], axis=1)
X_22_6 = X_22_6.iloc[2281:2565]


X_23_1 = X.drop(X.iloc[:, 8:], axis=1)
X_23_1 = X_23_1.iloc[2565:2694]


X_23_2 = X.drop(X.iloc[:, 1:8], axis=1)
X_23_2 = X_23_2.drop(X.iloc[:, 15:], axis=1)
X_23_2 = X_23_2.iloc[2565:2694]


X_23_3 = X.drop(X.iloc[:, 1:15], axis=1)
X_23_3 = X_23_3.drop(X.iloc[:, 22:], axis=1)
X_23_3 = X_23_3.iloc[2565:2694]


X_23_4 = X.drop(X.iloc[:, 1:22], axis=1)
X_23_4 = X_23_4.drop(X.iloc[:, 29:], axis=1)
X_23_4 = X_23_4.iloc[2565:2694]


X_23_5 = X.drop(X.iloc[:, 1:29], axis=1)
X_23_5 = X_23_5.drop(X.iloc[:, 36:], axis=1)
X_23_5 = X_23_5.iloc[2565:2694]


X_23_6 = X.drop(X.iloc[:, 1:36], axis=1)
X_23_6 = X_23_6.drop(X.iloc[:, 43:], axis=1)
X_23_6 = X_23_6.iloc[2565:2694]


X_24_1 = X.drop(X.iloc[:, 8:], axis=1)
X_24_1 = X_24_1.iloc[2694:2788]


X_24_2 = X.drop(X.iloc[:, 1:8], axis=1)
X_24_2 = X_24_2.drop(X.iloc[:, 15:], axis=1)
X_24_2 = X_24_2.iloc[2694:2788]


X_24_3 = X.drop(X.iloc[:, 1:15], axis=1)
X_24_3 = X_24_3.drop(X.iloc[:, 22:], axis=1)
X_24_3 = X_24_3.iloc[2694:2788]


X_24_4 = X.drop(X.iloc[:, 1:22], axis=1)
X_24_4 = X_24_4.drop(X.iloc[:, 29:], axis=1)
X_24_4 = X_24_4.iloc[2694:2788]


X_24_5 = X.drop(X.iloc[:, 1:29], axis=1)
X_24_5 = X_24_5.drop(X.iloc[:, 36:], axis=1)
X_24_5 = X_24_5.iloc[2694:2788]


X_24_6 = X.drop(X.iloc[:, 1:36], axis=1)
X_24_6 = X_24_6.drop(X.iloc[:, 43:], axis=1)
X_24_6 = X_24_6.iloc[2694:2788]


X_25_1 = X.drop(X.iloc[:, 8:], axis=1)
X_25_1 = X_25_1.iloc[2788:2891]


X_25_2 = X.drop(X.iloc[:, 1:8], axis=1)
X_25_2 = X_25_2.drop(X.iloc[:, 15:], axis=1)
X_25_2 = X_25_2.iloc[2788:2891]
X_25_2

X_25_3 = X.drop(X.iloc[:, 1:15], axis=1)
X_25_3 = X_25_3.drop(X.iloc[:, 22:], axis=1)
X_25_3 = X_25_3.iloc[2788:2891]


X_25_4 = X.drop(X.iloc[:, 1:22], axis=1)
X_25_4 = X_25_4.drop(X.iloc[:, 29:], axis=1)
X_25_4 = X_25_4.iloc[2788:2891]


X_25_5 = X.drop(X.iloc[:, 1:29], axis=1)
X_25_5 = X_25_5.drop(X.iloc[:, 36:], axis=1)
X_25_5 = X_25_5.iloc[2788:2891]


X_25_6 = X.drop(X.iloc[:, 1:36], axis=1)
X_25_6 = X_25_6.drop(X.iloc[:, 43:], axis=1)
X_25_6 = X_25_6.iloc[2788:2891]

# %%
X_25_6
# Out:
#         월  유역평균강수6  강우A6  강우B6  강우C6  강우D6  수위E6     수위D6
# 2788  7.0   0.0177     0     0     0     0  2.70  134.035
# 2789  7.0   1.0631     0     0    14     0  2.68  134.055
# 2790  7.0   2.9241     0     0    15     0  2.67  134.070
# 2791  7.0   3.3789     0     0    15     1  2.66  134.090
# 2792  7.0   3.8094     0     0    16     1  2.65  134.105
# ...   ...      ...   ...   ...   ...   ...   ...      ...
# 2886  7.0   1.7366     6     0     1     1  3.03  137.130
# 2887  7.0   1.7366     2     0     1     1  3.00  137.145
# 2888  7.0   1.7366     1     0     1     1  2.98  137.155
# 2889  7.0   1.7366     1     0     1     1  2.96  137.165
# 2890  7.0   1.7366     1     0     1     1  2.94  137.180
#
# [103 rows x 8 columns]

# %%
import pandas as pd
import numpy as np

from catboost import CatBoostRegressor
cat = CatBoostRegressor()

from sklearn.metrics import mean_squared_error
from sklearn.model_selection import train_test_split

# %%
train = pd.read_csv('C:/Users/Moon/Desktop/Github/BigContest_Flood-ZERO/고경수/train.csv')
test = pd.read_csv('C:/Users/Moon/Desktop/Github/BigContest_Flood-ZERO/고경수/test.csv')
submission = pd.read_csv('C:/Users/Moon/Desktop/Github/BigContest_Flood-ZERO/고경수/submission.csv')

# %%
유역평균강수 = ['유역평균강수1','유역평균강수2','유역평균강수3','유역평균강수4','유역평균강수5','유역평균강수6']
강우A = ['강우A1','강우A2','강우A3','강우A4','강우A5','강우A6']
강우B = ['강우B1','강우B2','강우B3','강우B4','강우B5','강우B6']
강우C = ['강우C1','강우C2','강우C3','강우C4','강우C5','강우C6']
강우D = ['강우D1','강우D2','강우D3','강우D4','강우D5','강우D6']
수위E = ['수위E1','수위E2','수위E3','수위E4','수위E5','수위E6']
수위D = ['수위D1','수위D2','수위D3','수위D4','수위D5','수위D6']

# %% [markdown]
# ---
# # 사상번호별 인덱스 정규화 추가

# %%
X = train.drop('유입량', axis=1)
y = train['유입량']

# %%
X_1 = X.iloc[:226]
X_2 = X.iloc[226:326]
X_3 = X.iloc[326:407]
X_4 = X.iloc[407:441]
X_5 = X.iloc[441:535]
X_6 = X.iloc[535:581]
X_7 = X.iloc[581:632]
X_8 = X.iloc[632:673]
X_9 = X.iloc[673:741]
X_10 = X.iloc[741:827]
X_11 = X.iloc[827:937]
X_12 = X.iloc[937:1064]
X_13 = X.iloc[1064:1131]
X_14 = X.iloc[1131:1181]
X_15 = X.iloc[1181:1443]
X_16 = X.iloc[1443:1648]
X_17 = X.iloc[1648:1773]
X_18 = X.iloc[1773:1838]
X_19 = X.iloc[1838:1933]
X_20 = X.iloc[1933:2197]
X_21 = X.iloc[2197:2281]
X_22 = X.iloc[2281:2565]
X_23 = X.iloc[2565:2694]
X_24 = X.iloc[2694:2788]
X_25 = X.iloc[2788:2891]

# %%
dtlists = []
index = pd.DataFrame()
for j in range(1, 26):
    eval('dtlists.append(X_'+str(j)+')')
    dtlists[j-1] = dtlists[j-1].reset_index()
    dtlists[j-1]['인덱스'] = dtlists[j-1].index
    dtlists[j-1]['정규화인덱스'] = dtlists[j-1]['인덱스'] / (len(dtlists[j-1])-1)
    index = pd.concat([index, pd.DataFrame(dtlists[j-1])])
    
index = index.reset_index()
train['정규화인덱스'] = index['정규화인덱스']

# %%
X_train, X_test, y_train, y_test = train_test_split(train[['정규화인덱스',*유역평균강수, *강우A, *강우B, *강우C, *강우D, *수위E, *수위D]],
                                                           train['유입량'], test_size=0.2109996, shuffle=False)

Original_train = X_train # 사상번호 1 ~ 21
Original_test = X_test # 사상번호 22 ~ 25

# %% [markdown]
# ---
# # 정규화 인덱스 추가 (집단5)

# %%
X_train = Original_train[['정규화인덱스', 유역평균강수[4], 강우A[4], 강우B[4], 강우C[4], 강우D[4],수위D[4], 수위E[4]]]
X_test = Original_test[['정규화인덱스', 유역평균강수[4], 강우A[4], 강우B[4], 강우C[4], 강우D[4],수위D[4], 수위E[4]]]

model = cat
model.fit(X_train, y_train)
# Out:
# Learning rate set to 0.045201
# 0:	learn: 2236.1668230	total: 1.58ms	remaining: 1.57s
# 1:	learn: 2160.0037963	total: 3.48ms	remaining: 1.74s
# 2:	learn: 2087.8194984	total: 5.04ms	remaining: 1.68s
# 3:	learn: 2017.4565989	total: 6.7ms	remaining: 1.67s
# 4:	learn: 1946.2035582	total: 8.25ms	remaining: 1.64s
# 5:	learn: 1880.2293331	total: 9.62ms	remaining: 1.59s
# 6:	learn: 1816.1895236	total: 11ms	remaining: 1.56s
# 7:	learn: 1758.3634566	total: 12.5ms	remaining: 1.54s
# 8:	learn: 1701.7040691	total: 14ms	remaining: 1.54s
# 9:	learn: 1646.7363090	total: 15.4ms	remaining: 1.52s
# 10:	learn: 1594.2289122	total: 16.9ms	remaining: 1.52s
# 11:	learn: 1543.2763398	total: 18.6ms	remaining: 1.53s
# 12:	learn: 1498.1519514	total: 19.9ms	remaining: 1.51s
# 13:	learn: 1451.6544753	total: 21.5ms	remaining: 1.51s
# 14:	learn: 1405.7064355	total: 23ms	remaining: 1.51s
# 15:	learn: 1362.9803350	total: 24.6ms	remaining: 1.51s
# 16:	learn: 1321.7854178	total: 26ms	remaining: 1.51s
# ...

# %%
pred = model.predict(X_test)

# %%
rmse = (np.sqrt(np.mean(mean_squared_error(y_test, pred))))
rmse
# Out:
# 401.55289474874183

# %% [markdown]
# # 집단 별 test data RMSE

# %% [markdown]
# ## 집단1 테스트

# %%
X_test = Original_test[['정규화인덱스', 유역평균강수[0], 강우A[0], 강우B[0], 강우C[0], 강우D[0],수위D[0], 수위E[0]]]

X_test.columns=['정규화인덱스', '유역평균강수5', '강우A5', '강우B5', '강우C5', '강우D5', '수위D5', '수위E5'] # 열 이름 감제 병합

pred = model.predict(X_test)

rmse = (np.sqrt(np.mean(mean_squared_error(y_test, pred))))
rmse
# Out:
# 390.69594448753105

# %% [markdown]
# ## 집단2 테스트

# %%
X_test = Original_test[['정규화인덱스', 유역평균강수[1], 강우A[1], 강우B[1], 강우C[1], 강우D[1],수위D[1], 수위E[1]]]

X_test.columns=['정규화인덱스', '유역평균강수5', '강우A5', '강우B5', '강우C5', '강우D5', '수위D5', '수위E5'] # 열 이름 감제 병합

pred = model.predict(X_test)

rmse = (np.sqrt(np.mean(mean_squared_error(y_test, pred))))
rmse
# Out:
# 388.9520759430114

# %% [markdown]
# ## 집단3 테스트

# %%
X_test = Original_test[['정규화인덱스', 유역평균강수[2], 강우A[2], 강우B[2], 강우C[2], 강우D[2],수위D[2], 수위E[2]]]

X_test.columns=['정규화인덱스', '유역평균강수5', '강우A5', '강우B5', '강우C5', '강우D5', '수위D5', '수위E5'] # 열 이름 감제 병합

pred = model.predict(X_test)

rmse = (np.sqrt(np.mean(mean_squared_error(y_test, pred))))
rmse
# Out:
# 384.1080021360355

# %% [markdown]
# ## 집단4 테스트

# %%
X_test = Original_test[['정규화인덱스', 유역평균강수[3], 강우A[3], 강우B[3], 강우C[3], 강우D[3],수위D[3], 수위E[3]]]

X_test.columns=['정규화인덱스', '유역평균강수5', '강우A5', '강우B5', '강우C5', '강우D5', '수위D5', '수위E5'] # 열 이름 감제 병합

pred = model.predict(X_test)

rmse = (np.sqrt(np.mean(mean_squared_error(y_test, pred))))
rmse
# Out:
# 404.0104522206291

# %% [markdown]
# ## 집단6 테스트

# %%
X_test = Original_test[['정규화인덱스', 유역평균강수[5], 강우A[5], 강우B[5], 강우C[5], 강우D[5],수위D[5], 수위E[5]]]

X_test.columns=['정규화인덱스', '유역평균강수5', '강우A5', '강우B5', '강우C5', '강우D5', '수위D5', '수위E5'] # 열 이름 감제 병합

pred = model.predict(X_test)

rmse = (np.sqrt(np.mean(mean_squared_error(y_test, pred))))
rmse
# Out:
# 382.5148183707216

# %%
X_1_2
# Out:
#        월  유역평균강수2  강우A2  강우B2  강우C2  강우D2  수위E2        수위D2
# 0    7.0      6.3     7     7     7     8  2.54  122.541667
# 1    7.0      6.4     7     8     7     8  2.53  122.550000
# 2    7.0      7.3     7     9     7     8  2.53  122.558333
# 3    7.0      8.2     7    10     8     8  2.53  122.566667
# 4    7.0     11.3     9    12    10    10  2.53  122.575000
# ..   ...      ...   ...   ...   ...   ...   ...         ...
# 221  7.0    108.8   129    91    76    82  7.48  141.766667
# 222  7.0    107.2   128    89    72    81  7.35  141.716667
# 223  7.0    105.3   126    88    71    80  7.25  141.658333
# 224  7.0    103.2   125    86    70    79  7.14  141.600000
# 225  7.0    101.2   121    84    68    78  7.02  141.533333
#
# [226 rows x 8 columns]

# %% [markdown]
# # 다른 모델과 비교

# %%
from xgboost import XGBRegressor
from lightgbm import LGBMRegressor

# %% [markdown]
# ## XGBoostRegressor

# %%
X_train = Original_train[['정규화인덱스', 유역평균강수[4], 강우A[4], 강우B[4], 강우C[4], 강우D[4],수위D[4], 수위E[4]]]
X_test = Original_test[['정규화인덱스', 유역평균강수[4], 강우A[4], 강우B[4], 강우C[4], 강우D[4],수위D[4], 수위E[4]]]

model = XGBRegressor()
model.fit(X_train, y_train)
# Out:
# XGBRegressor(base_score=0.5, booster='gbtree', colsample_bylevel=1,
#              colsample_bynode=1, colsample_bytree=1, gamma=0, gpu_id=-1,
#              importance_type='gain', interaction_constraints='',
#              learning_rate=0.300000012, max_delta_step=0, max_depth=6,
#              min_child_weight=1, missing=nan, monotone_constraints='()',
#              n_estimators=100, n_jobs=16, num_parallel_tree=1, random_state=0,
#              reg_alpha=0, reg_lambda=1, scale_pos_weight=1, subsample=1,
#              tree_method='exact', validate_parameters=1, verbosity=None)

# %%
pred = model.predict(X_test)

# %%
rmse = (np.sqrt(np.mean(mean_squared_error(y_test, pred))))
rmse
# Out:
# 486.54702540693813

# %% [markdown]
# ## LGBMRegreessor

# %%
X_train = Original_train[['정규화인덱스', 유역평균강수[4], 강우A[4], 강우B[4], 강우C[4], 강우D[4],수위D[4], 수위E[4]]]
X_test = Original_test[['정규화인덱스', 유역평균강수[4], 강우A[4], 강우B[4], 강우C[4], 강우D[4],수위D[4], 수위E[4]]]

model = LGBMRegressor()
model.fit(X_train, y_train)
# Out:
# LGBMRegressor()

# %%
pred = model.predict(X_test)

# %%
rmse = (np.sqrt(np.mean(mean_squared_error(y_test, pred))))
rmse
# Out:
# 496.15361418236785

# %% [markdown]
# ## 앙상블 실험

# %%
model = cat
model.fit(X_train, y_train)

# %%
X_test = Original_test[['정규화인덱스', 유역평균강수[0], 강우A[0], 강우B[0], 강우C[0], 강우D[0],수위D[0], 수위E[0]]]
X_test.columns=['정규화인덱스', '유역평균강수5', '강우A5', '강우B5', '강우C5', '강우D5', '수위D5', '수위E5'] # 열 이름 감제 병합
pred1 = model.predict(X_test)

X_test = Original_test[['정규화인덱스', 유역평균강수[1], 강우A[1], 강우B[1], 강우C[1], 강우D[1],수위D[1], 수위E[1]]]
X_test.columns=['정규화인덱스', '유역평균강수5', '강우A5', '강우B5', '강우C5', '강우D5', '수위D5', '수위E5'] # 열 이름 감제 병합
pred2 = model.predict(X_test)

X_test = Original_test[['정규화인덱스', 유역평균강수[2], 강우A[2], 강우B[2], 강우C[2], 강우D[2],수위D[2], 수위E[2]]]
X_test.columns=['정규화인덱스', '유역평균강수5', '강우A5', '강우B5', '강우C5', '강우D5', '수위D5', '수위E5'] # 열 이름 감제 병합
pred3 = model.predict(X_test)

X_test = Original_test[['정규화인덱스', 유역평균강수[3], 강우A[3], 강우B[3], 강우C[3], 강우D[3],수위D[3], 수위E[3]]]
X_test.columns=['정규화인덱스', '유역평균강수5', '강우A5', '강우B5', '강우C5', '강우D5', '수위D5', '수위E5'] # 열 이름 감제 병합
pred4 = model.predict(X_test)

X_test = Original_test[['정규화인덱스', 유역평균강수[4], 강우A[4], 강우B[4], 강우C[4], 강우D[4],수위D[4], 수위E[4]]]
X_test.columns=['정규화인덱스', '유역평균강수5', '강우A5', '강우B5', '강우C5', '강우D5', '수위D5', '수위E5'] # 열 이름 감제 병합
pred5 = model.predict(X_test)

X_test = Original_test[['정규화인덱스', 유역평균강수[5], 강우A[5], 강우B[5], 강우C[5], 강우D[5],수위D[5], 수위E[5]]]
X_test.columns=['정규화인덱스', '유역평균강수5', '강우A5', '강우B5', '강우C5', '강우D5', '수위D5', '수위E5'] # 열 이름 감제 병합
pred6 = model.predict(X_test)

# %%
mean_preds = (pred1 + pred2 + pred3 + pred4 + pred5 + pred6) / 6
print(pred1[:10])
print(pred2[:10])
print(pred3[:10])
print(pred4[:10])
mean_preds[:10]
# Out:
# [102.8369629  102.12042494 102.12042494 100.47228876 101.27552589
#  101.27552589  99.89998436  99.89998436 110.48894336 110.79943676]
# [102.8369629  102.12042494 102.12042494 100.47228876 101.27552589
#  101.27552589  99.89998436  99.89998436 110.48894336 110.79943676]
# [102.8369629  102.12042494 102.12042494 100.47228876 101.27552589
#  101.27552589  99.89998436  99.89998436 110.48894336 110.79943676]
# [102.8369629  102.12042494 102.12042494 100.47228876 101.27552589
#  101.27552589  99.89998436  99.89998436 110.48894336 110.79943676]
# array([101.83305321, 100.3575973 , 101.11651525,  99.59087494,
#        101.15303001, 100.39411206,  99.01857054,  99.01857054,
#        109.60752954, 109.79552706])

# %%
rmse = (np.sqrt(np.mean(mean_squared_error(y_test, mean_preds))))
rmse
# Out:
# 382.8509365668351
