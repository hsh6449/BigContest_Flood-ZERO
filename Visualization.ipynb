# %%
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
import matplotlib as mpl
from matplotlib import font_manager, rc
import re
import warnings
warnings.filterwarnings('ignore')

# %%
from matplotlib import font_manager, rc

 

import matplotlib

 

font_name = font_manager.FontProperties(fname="c:/Windows/Fonts/malgun.ttf").get_name()

rc('font', family=font_name)

matplotlib.rcParams['axes.unicode_minus'] = False

# %%
train = pd.read_csv('C:/Users/Moon/Desktop/Github/BigContest_Flood-ZERO/문우혁/Data/dam_train.csv')
test = pd.read_csv('C:/Users/Moon/Desktop/Github/BigContest_Flood-ZERO/문우혁/Data/dam_test.csv')
submission = pd.read_csv('C:/Users/Moon/Desktop/Github/BigContest_Flood-ZERO/문우혁/Data/submission.csv')

# %%
X = train.drop(['유입량'], axis=1)
y = train['유입량']

# %%
for i, col in enumerate(X.columns):
  plt.figure(figsize=(8,4))
  plt.scatter(train[col], train['유입량'], s=1)
  plt.ylabel('유입량', size=12)
  plt.xlabel(col, size=12)
  plt.tight_layout()
