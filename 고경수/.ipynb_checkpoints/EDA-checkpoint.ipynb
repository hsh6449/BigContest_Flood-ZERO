# %%
import pandas as pd
import numpy as np
import seaborn as sns

import matplotlib.pyplot as plt
# %matplotlib inline

import platform

if platform.system() == 'Darwin': # Mac 환경 폰트 설정
    plt.rc('font', family='AppleGothic')
elif platform.system() == 'Windows': # Windows 환경 폰트 설정
    plt.rc('font', family='Malgun Gothic')

plt.rc('axes', unicode_minus=False) # 마이너스 폰트 설정

# %config InlineBackend.figure_format = 'retina'

plt.rcParams["figure.figsize"] = (12, 9)

# %%
train = pd.read_csv('G:/내 드라이브/Github/BigContest_Flood-ZERO/고경수/train.csv')
test = pd.read_csv('G:/내 드라이브/Github/BigContest_Flood-ZERO/고경수/test.csv')
submission = pd.read_csv('G:/내 드라이브/Github/BigContest_Flood-ZERO/고경수/submission.csv')

# %% [markdown]
# # `-`집단 1개만을 사용하여 비교

# %%
data = train[['홍수사상번호', '연', '월', '일', '시간', '유입량', '유역평균강수1', '강우A1', '강우B1', '강우C1',
       '강우D1', '수위E1', '수위D1']]

# %% [markdown]
# ---

# %% [markdown]
# # '유입량' 상관계수 분석

# %%
data.corr()['유입량'].plot(kind='barh')
# Out:
# <AxesSubplot:>

# %% [markdown]
# - 수위 D와는 낮은 상관계수를 보인다..

# %% [markdown]
# - 시간의 경우도 낮은 상관계수를 보이나, 예측에는 도움을 주는듯 보임. (rmse 비교했을 때)

# %% [markdown]
# ---

# %% [markdown]
# # '유역평균강수' 상관계수 분석

# %%
data.corr()['유역평균강수1'].plot(kind='barh')
# Out:
# <AxesSubplot:>

# %% [markdown]
# - 유역평균강수와 강우 A, B, C, D는 상관관계가 있어 둘다 사용하는 것은 좋지 않아보인다.

# %% [markdown]
# - 다만 유역평균강수에 현재 변수에는 존재하지 않는 강우 E에 대한 정보가 있을 수 있으므로, 산출식을 알면 파생변수를 만들어 사용할 수 있을 것

# %% [markdown]
# ---
# # 연도 EDA

# %%
train.groupby('연').count()['유입량'].plot(kind='barh')
# Out:
# <AxesSubplot:ylabel='연'>

# %% [markdown]
# - 연도별 발생 횟수

# %%
train.groupby('연').mean()['유입량'].plot(kind='barh')
# Out:
# <AxesSubplot:ylabel='연'>

# %% [markdown]
# - 연도별 평균 유입량

# %%
data.plot(x='연', y='유입량', kind='scatter')
# Out:
# <AxesSubplot:xlabel='연', ylabel='유입량'>

# %% [markdown]
# - 연도별 유입량 분포

# %% [markdown]
# `연도는 의미 없다고 생각. 주어진 데이터는 2018년 이전의 데이터, 예측해야하는 것은 2018년의 데이터`

# %% [markdown]
# ---
# # 월 EDA

# %%
data.plot(x='월', y='유입량', kind='scatter')
# Out:
# <AxesSubplot:xlabel='월', ylabel='유입량'>

# %% [markdown]
# - 월별 유입량 분포

# %%
data.groupby('월').mean()['유입량'].plot(kind='barh')
# Out:
# <AxesSubplot:ylabel='월'>

# %% [markdown]
# - 월별 평균 유입량

# %%
data.groupby('월').count()['유입량'].plot(kind='barh')
# Out:
# <AxesSubplot:ylabel='월'>

# %% [markdown]
# - 월별 발생 횟수

# %% [markdown]
# `7월이 장마가 있어서 그런지 많은 발생횟수를 보임. 6월은 표본이 너무 적고, 8월은 다른 월에 비해 평균 유입량이 낮음. `
#
# `+ 예측해야하는 것은 2018년 7월의 유입량`

# %% [markdown]
# ---
# # 시간 EDA

# %%
data.plot(x='시간', y='유입량', kind='scatter')
# Out:
# <AxesSubplot:xlabel='시간', ylabel='유입량'>

# %% [markdown]
# - 시간에 따른 유입량

# %%
train.groupby('시간').mean()['유입량'].plot(kind='barh')
# Out:
# <AxesSubplot:ylabel='시간'>

# %% [markdown]
# - 시간에 따른 유입량 평균

# %%
train.groupby('시간').count()['유입량'].plot(kind='barh')
# Out:
# <AxesSubplot:ylabel='시간'>

# %% [markdown]
# - 시간에 따른 발생횟수

# %% [markdown]
# '시간' 변수를 추가했을때 점수는 좋아졌음
#
# 유입량과의 상관계수는 낮음

# %%
data.corr()['유입량']['시간']
# Out:
# 0.016275561773972713

# %% [markdown]
# ---

# %% [markdown]
# # 유입량과 변수간의 산점도

# %%
data.columns
# Out:
# Index(['홍수사상번호', '연', '월', '일', '시간', '유입량', '유역평균강수1', '강우A1', '강우B1', '강우C1',
#        '강우D1', '수위E1', '수위D1'],
#       dtype='object')

# %%
data.plot(x = '유역평균강수1' , y = '유입량', kind = 'scatter')
# Out:
# <AxesSubplot:xlabel='유역평균강수1', ylabel='유입량'>

# %% [markdown]
# - 유입량 ~ 유역평균강수

# %% [markdown]
# 상관계수 : 0.742268

# %%
data.plot(x = '강우A1' , y = '유입량', kind = 'scatter')
# Out:
# <AxesSubplot:xlabel='강우A1', ylabel='유입량'>

# %% [markdown]
# - 유입량 ~ 강우A

# %% [markdown]
# 상관계수 : 0.617424

# %%
data.plot(x = '강우B1' , y = '유입량', kind = 'scatter')
# Out:
# <AxesSubplot:xlabel='강우B1', ylabel='유입량'>

# %% [markdown]
# - 유입량 ~ 강우B

# %% [markdown]
# 상관계수 : 0.739951

# %%
data.plot(x = '강우C1' , y = '유입량', kind = 'scatter')
# Out:
# <AxesSubplot:xlabel='강우C1', ylabel='유입량'>

# %% [markdown]
# - 유입량 ~ 강우C

# %% [markdown]
# 상관계수 : 0.605588

# %%
data.plot(x = '강우D1' , y = '유입량', kind = 'scatter')
# Out:
# <AxesSubplot:xlabel='강우D1', ylabel='유입량'>

# %% [markdown]
# - 유입량 ~ 강우D

# %% [markdown]
# 상관계수 : 0.700568

# %%
data.plot(x = '수위D1' , y = '유입량', kind = 'scatter')
# Out:
# <AxesSubplot:xlabel='수위D1', ylabel='유입량'>

# %% [markdown]
# - 유입량 ~ 수위D

# %% [markdown]
# 상관계수 : 0.109475

# %%
data.plot(x = '수위E1' , y = '유입량', kind = 'scatter')
# Out:
# <AxesSubplot:xlabel='수위E1', ylabel='유입량'>

# %% [markdown]
# - 유입량 ~ 수위E

# %% [markdown]
# 상관계수 : 0.903840
