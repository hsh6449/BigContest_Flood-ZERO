# %%
import pandas as pd
from sklearn.metrics import mean_squared_error
from sklearn.model_selection import train_test_split

from catboost import CatBoostRegressor
cat = CatBoostRegressor()

# %%
train = pd.read_csv('G:/내 드라이브/Github/BigContest_Flood-ZERO/고경수/train.csv')
test = pd.read_csv('G:/내 드라이브/Github/BigContest_Flood-ZERO/고경수/test.csv')
submission = pd.read_csv('G:/내 드라이브/Github/BigContest_Flood-ZERO/고경수/submission.csv')

# %%
df_1 = train[['홍수사상번호', '연', '월', '일', '시간', '유입량', 
              '유역평균강수1', '강우A1', '강우B1', '강우C1','강우D1', '수위E1', '수위D1','열번호']]
df_2 = train[['홍수사상번호', '연', '월', '일', '시간', '유입량', 
              '유역평균강수2', '강우A2', '강우B2', '강우C2','강우D2', '수위E2', '수위D2','열번호']]
df_3 = train[['홍수사상번호', '연', '월', '일', '시간', '유입량', 
              '유역평균강수3', '강우A3', '강우B3', '강우C3','강우D3', '수위E3', '수위D3','열번호']]
df_4 = train[['홍수사상번호', '연', '월', '일', '시간', '유입량', 
              '유역평균강수4', '강우A4', '강우B4', '강우C4','강우D4', '수위E4', '수위D4','열번호']]
df_5 = train[['홍수사상번호', '연', '월', '일', '시간', '유입량', 
              '유역평균강수5', '강우A5', '강우B5', '강우C5','강우D5', '수위E5', '수위D5','열번호']]
df_6 = train[['홍수사상번호', '연', '월', '일', '시간', '유입량', 
              '유역평균강수6', '강우A6', '강우B6', '강우C6','강우D6', '수위E6', '수위D6','열번호']]

df_1.columns = ['홍수사상번호','연', '월', '일', '시간','유입량',
                '유역평균강수','강우A','강우B','강우C','강우D','수위E','수위D','열번호']
df_2.columns = ['홍수사상번호','연', '월', '일', '시간','유입량',
                '유역평균강수','강우A','강우B','강우C','강우D','수위E','수위D','열번호']
df_3.columns = ['홍수사상번호','연', '월', '일', '시간','유입량',
                '유역평균강수','강우A','강우B','강우C','강우D','수위E','수위D','열번호']
df_4.columns = ['홍수사상번호','연', '월', '일', '시간','유입량',
                '유역평균강수','강우A','강우B','강우C','강우D','수위E','수위D','열번호']
df_5.columns = ['홍수사상번호','연', '월', '일', '시간','유입량',
                '유역평균강수','강우A','강우B','강우C','강우D','수위E','수위D','열번호']
df_6.columns = ['홍수사상번호','연', '월', '일', '시간','유입량',
                '유역평균강수','강우A','강우B','강우C','강우D','수위E','수위D','열번호']
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-17-ec40029976de> in <module>
# ----> 1 df_1 = train[['홍수사상번호', '연', '월', '일', '시간', '유입량',
#       2               '유역평균강수1', '강우A1', '강우B1', '강우C1','강우D1', '수위E1', '수위D1','열번호']]
#       3 df_2 = train[['홍수사상번호', '연', '월', '일', '시간', '유입량',
#       4               '유역평균강수2', '강우A2', '강우B2', '강우C2','강우D2', '수위E2', '수위D2','열번호']]
#       5 df_3 = train[['홍수사상번호', '연', '월', '일', '시간', '유입량',
#
# C:\ProgramData\Anaconda3\envs\py38r40\lib\site-packages\pandas\core\frame.py in __getitem__(self, key)
#    3028             if is_iterator(key):
#    3029                 key = list(key)
# -> 3030             indexer = self.loc._get_listlike_indexer(key, axis=1, raise_missing=True)[1]
#    3031
#    3032         # take() does not accept boolean indexers
#
# C:\ProgramData\Anaconda3\envs\py38r40\lib\site-packages\pandas\core\indexing.py in _get_listlike_indexer(self, key, axis, raise_missing)
#    1264             keyarr, indexer, new_indexer = ax._reindex_non_unique(keyarr)
#    1265
# -> 1266         self._validate_read_indexer(keyarr, indexer, axis, raise_missing=raise_missing)
#    1267         return keyarr, indexer
#    1268
#
# C:\ProgramData\Anaconda3\envs\py38r40\lib\site-packages\pandas\core\indexing.py in _validate_read_indexer(self, key, indexer, axis, raise_missing)
#    1314             if raise_missing:
#    1315                 not_found = list(set(key) - set(ax))
# -> 1316                 raise KeyError(f"{not_found} not in index")
#    1317
#    1318             not_found = key[missing_mask]
#
# KeyError: "['열번호'] not in index"

# %%
train = pd.concat([df_1,df_2,df_3,df_4,df_5,df_6], axis=0)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-14-70edf5312c4d> in <module>
# ----> 1 train = pd.concat([df_1,df_2,df_3,df_4,df_5,df_6], axis=0)
#
# NameError: name 'df_1' is not defined

# %%
train = train.sort_values(by='열번호')

# %%
from pycaret.regression import *

# %%
X = train[['홍수사상번호','연', '월', '일', '시간',
                '유역평균강수','강우A','강우B','강우C','강우D','수위E','수위D','열번호']]

y = train['유입량']
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-7-b284780ccbd3> in <module>
# ----> 1 X = train[['홍수사상번호','연', '월', '일', '시간',
#       2                 '유역평균강수','강우A','강우B','강우C','강우D','수위E','수위D','열번호']]
#       3
#       4 y = train['유입량']
#
# C:\ProgramData\Anaconda3\envs\py38r40\lib\site-packages\pandas\core\frame.py in __getitem__(self, key)
#    3028             if is_iterator(key):
#    3029                 key = list(key)
# -> 3030             indexer = self.loc._get_listlike_indexer(key, axis=1, raise_missing=True)[1]
#    3031
#    3032         # take() does not accept boolean indexers
#
# C:\ProgramData\Anaconda3\envs\py38r40\lib\site-packages\pandas\core\indexing.py in _get_listlike_indexer(self, key, axis, raise_missing)
#    1264             keyarr, indexer, new_indexer = ax._reindex_non_unique(keyarr)
#    1265
# -> 1266         self._validate_read_indexer(keyarr, indexer, axis, raise_missing=raise_missing)
#    1267         return keyarr, indexer
#    1268
#
# C:\ProgramData\Anaconda3\envs\py38r40\lib\site-packages\pandas\core\indexing.py in _validate_read_indexer(self, key, indexer, axis, raise_missing)
#    1314             if raise_missing:
#    1315                 not_found = list(set(key) - set(ax))
# -> 1316                 raise KeyError(f"{not_found} not in index")
#    1317
#    1318             not_found = key[missing_mask]
#
# KeyError: "['열번호', '수위E', '강우A', '유역평균강수', '강우D', '수위D', '강우C', '강우B'] not in index"

# %%
X['월'] = X['월'].astype(str)
X['일'] = X['일'].astype(str)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-8-34d435596728> in <module>
# ----> 1 X['월'] = X['월'].astype(str)
#       2 X['일'] = X['일'].astype(str)
#
# NameError: name 'X' is not defined

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y, shuffle=False, test_size=0.2)

categorical_features_indices1 = np.where(X_train.dtypes == np.object)[0]
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-9-ac64dca49089> in <module>
# ----> 1 X_train, X_test, y_train, y_test = train_test_split(X, y, shuffle=False, test_size=0.2)
#       2
#       3 categorical_features_indices1 = np.where(X_train.dtypes == np.object)[0]
#
# NameError: name 'X' is not defined

# %%
X_train
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-10-931765772341> in <module>
# ----> 1 X_train
#
# NameError: name 'X_train' is not defined

# %%
X_train, X_test = train_test_split(X, test_size=0.2, shuffle = False, random_state = 40)
categorical_features_indices = np.where(X_train.dtypes == np.object)[0]

# %%
model = cat

# %%
model.fit(X_train, y_train, cat_features = categorical_features_indices1)

# %%
pred = model.predict(X_test)

# %%
rmse = (np.sqrt(np.mean(mean_squared_error(y_test, pred))))

# %%
rmse
# Out:
# 575.5808171325568

# %%
X_train
# Out:
#       홍수사상번호       연    월     일    시간         유입량  유역평균강수  강우A  강우B  강우C  강우D  \
# 0        1.0  2006.0  7.0  10.0   8.0  189.100000  6.4000    7    7    7    8
# 0        1.0  2006.0  7.0  10.0   8.0  189.100000  6.3000    7    7    7    8
# 0        1.0  2006.0  7.0  10.0   8.0  189.100000  6.4000    7    7    8    8
# 0        1.0  2006.0  7.0  10.0   8.0  189.100000  6.3000    7    7    7    8
# 0        1.0  2006.0  7.0  10.0   8.0  189.100000  6.4000    7    7    8    8
# ...      ...     ...  ...   ...   ...         ...     ...  ...  ...  ...  ...
# 2311    22.0  2013.0  7.0   8.0  20.0  186.106828  7.0789   23    0    3    2
# 2312    22.0  2013.0  7.0   8.0  21.0  180.463346  7.5385   23    0    3    3
# 2312    22.0  2013.0  7.0   8.0  21.0  180.463346  7.4782   23    0    3    3
# 2312    22.0  2013.0  7.0   8.0  21.0  180.463346  7.0789   23    0    3    2
# 2312    22.0  2013.0  7.0   8.0  21.0  180.463346  7.5385   23    0    3    3
#
#        수위E         수위D   열번호
# 0     2.54  122.568750     0
# 0     2.54  122.550000     0
# 0     2.54  122.660000     0
# 0     2.54  122.541667     0
# 0     2.54  122.610000     0
# ...    ...         ...   ...
# 2311  1.97  124.600000  2311
# 2312  1.97  124.600000  2312
# 2312  1.97  124.600000  2312
# 2312  1.97  124.600000  2312
# 2312  1.97  124.600000  2312
#
# [13876 rows x 14 columns]

# %%
X_test
# Out:
#       홍수사상번호       연    월     일    시간         유입량  유역평균강수  강우A  강우B  강우C  강우D  \
# 2312    22.0  2013.0  7.0   8.0  21.0  180.463346  7.0789   23    0    3    2
# 2312    22.0  2013.0  7.0   8.0  21.0  180.463346  7.0021   23    0    3    2
# 2313    22.0  2013.0  7.0   8.0  22.0  171.394779  7.5385   23    0    3    2
# 2313    22.0  2013.0  7.0   8.0  22.0  171.394779  7.5385   23    0    3    2
# 2313    22.0  2013.0  7.0   8.0  22.0  171.394779  7.0789   23    0    3    2
# ...      ...     ...  ...   ...   ...         ...     ...  ...  ...  ...  ...
# 2890    25.0  2017.0  7.0  18.0  22.0  470.458109  2.1142    1    0    1    1
# 2890    25.0  2017.0  7.0  18.0  22.0  470.458109  2.7514    1    0    1    1
# 2890    25.0  2017.0  7.0  18.0  22.0  470.458109  3.2841    1    0    1    1
# 2890    25.0  2017.0  7.0  18.0  22.0  470.458109  1.7908    1    0    1    1
# 2890    25.0  2017.0  7.0  18.0  22.0  470.458109  1.7366    1    0    1    1
#
#        수위E         수위D   열번호
# 2312  1.97  124.600000  2312
# 2312  1.97  124.600000  2312
# 2313  1.97  124.600000  2313
# 2313  1.97  124.600000  2313
# 2313  1.97  124.600000  2313
# ...    ...         ...   ...
# 2890  2.94  137.121429  2890
# 2890  2.94  137.208333  2890
# 2890  2.94  137.206250  2890
# 2890  2.94  137.152000  2890
# 2890  2.94  137.180000  2890
#
# [3470 rows x 14 columns]

# %%
reg = setup(session_id=1,
            data=X_train[['홍수사상번호','연', '월', '시간','유입량',
                '유역평균강수','강우A','강우B','강우C','강우D','수위E','수위D']],
            target='유입량',
            numeric_imputation = 'mean',
            normalize = True,
            categorical_features=['홍수사상번호','연','월'],
            silent=True)
# Out:
# <style  type="text/css" >
# #T_fb123_row0_col1,#T_fb123_row27_col1{
#             background-color:  lightgreen;
#         }</style><table id="T_fb123_" ><thead>    <tr>        <th class="blank level0" ></th>        <th class="col_heading level0 col0" >Description</th>        <th class="col_heading level0 col1" >Value</th>    </tr></thead><tbody>
#                 <tr>
#                         <th id="T_fb123_level0_row0" class="row_heading level0 row0" >0</th>
#                         <td id="T_fb123_row0_col0" class="data row0 col0" >session_id</td>
#                         <td id="T_fb123_row0_col1" class="data row0 col1" >1</td>
#             </tr>
#             <tr>
#                         <th id="T_fb123_level0_row1" class="row_heading level0 row1" >1</th>
#                         <td id="T_fb123_row1_col0" class="data row1 col0" >Target</td>
#                         <td id="T_fb123_row1_col1" class="data row1 col1" >유입량</td>
#             </tr>
#             <tr>
#                         <th id="T_fb123_level0_row2" class="row_heading level0 row2" >2</th>
#                         <td id="T_fb123_row2_col0" class="data row2 col0" >Original Data</td>
#                         <td id="T_fb123_row2_col1" class="data row2 col1" >(13876, 12)</td>
#             </tr>
#             <tr>
#                         <th id="T_fb123_level0_row3" class="row_heading level0 row3" >3</th>
#                         <td id="T_fb123_row3_col0" class="data row3 col0" >Missing Values</td>
#                         <td id="T_fb123_row3_col1" class="data row3 col1" >False</td>
#             </tr>
#             <tr>
#                         <th id="T_fb123_level0_row4" class="row_heading level0 row4" >4</th>
#                         <td id="T_fb123_row4_col0" class="data row4 col0" >Numeric Features</td>
#                         <td id="T_fb123_row4_col1" class="data row4 col1" >8</td>
#             </tr>
#             <tr>
#                         <th id="T_fb123_level0_row5" class="row_heading level0 row5" >5</th>
#                         <td id="T_fb123_row5_col0" class="data row5 col0" >Categorical Features</td>
#                         <td id="T_fb123_row5_col1" class="data row5 col1" >3</td>
#             </tr>
#             <tr>
#                         <th id="T_fb123_level0_row6" class="row_heading level0 row6" >6</th>
#                         <td id="T_fb123_row6_col0" class="data row6 col0" >Ordinal Features</td>
#                         <td id="T_fb123_row6_col1" class="data row6 col1" >False</td>
#             </tr>
#             <tr>
#                         <th id="T_fb123_level0_row7" class="row_heading level0 row7" >7</th>
#                         <td id="T_fb123_row7_col0" class="data row7 col0" >High Cardinality Features</td>
#                         <td id="T_fb123_row7_col1" class="data row7 col1" >False</td>
#             </tr>
#             <tr>
#                         <th id="T_fb123_level0_row8" class="row_heading level0 row8" >8</th>
#                         <td id="T_fb123_row8_col0" class="data row8 col0" >High Cardinality Method</td>
#                         <td id="T_fb123_row8_col1" class="data row8 col1" >None</td>
#             </tr>
#             <tr>
#                         <th id="T_fb123_level0_row9" class="row_heading level0 row9" >9</th>
#                         <td id="T_fb123_row9_col0" class="data row9 col0" >Transformed Train Set</td>
#                         <td id="T_fb123_row9_col1" class="data row9 col1" >(9713, 40)</td>
#             </tr>
#             <tr>
#                         <th id="T_fb123_level0_row10" class="row_heading level0 row10" >10</th>
#                         <td id="T_fb123_row10_col0" class="data row10 col0" >Transformed Test Set</td>
#                         <td id="T_fb123_row10_col1" class="data row10 col1" >(4163, 40)</td>
#             </tr>
#             <tr>
#                         <th id="T_fb123_level0_row11" class="row_heading level0 row11" >11</th>
#                         <td id="T_fb123_row11_col0" class="data row11 col0" >Shuffle Train-Test</td>
#                         <td id="T_fb123_row11_col1" class="data row11 col1" >True</td>
#             </tr>
#             <tr>
#                         <th id="T_fb123_level0_row12" class="row_heading level0 row12" >12</th>
#                         <td id="T_fb123_row12_col0" class="data row12 col0" >Stratify Train-Test</td>
#                         <td id="T_fb123_row12_col1" class="data row12 col1" >False</td>
#             </tr>
#             <tr>
#                         <th id="T_fb123_level0_row13" class="row_heading level0 row13" >13</th>
#                         <td id="T_fb123_row13_col0" class="data row13 col0" >Fold Generator</td>
#                         <td id="T_fb123_row13_col1" class="data row13 col1" >KFold</td>
#             </tr>
#             <tr>
#                         <th id="T_fb123_level0_row14" class="row_heading level0 row14" >14</th>
#                         <td id="T_fb123_row14_col0" class="data row14 col0" >Fold Number</td>
#                         <td id="T_fb123_row14_col1" class="data row14 col1" >10</td>
#             </tr>
#             <tr>
#                         <th id="T_fb123_level0_row15" class="row_heading level0 row15" >15</th>
#                         <td id="T_fb123_row15_col0" class="data row15 col0" >CPU Jobs</td>
#                         <td id="T_fb123_row15_col1" class="data row15 col1" >-1</td>
#             </tr>
#             <tr>
#                         <th id="T_fb123_level0_row16" class="row_heading level0 row16" >16</th>
#                         <td id="T_fb123_row16_col0" class="data row16 col0" >Use GPU</td>
#                         <td id="T_fb123_row16_col1" class="data row16 col1" >False</td>
#             </tr>
#             <tr>
#                         <th id="T_fb123_level0_row17" class="row_heading level0 row17" >17</th>
#                         <td id="T_fb123_row17_col0" class="data row17 col0" >Log Experiment</td>
#                         <td id="T_fb123_row17_col1" class="data row17 col1" >False</td>
#             </tr>
#             <tr>
#                         <th id="T_fb123_level0_row18" class="row_heading level0 row18" >18</th>
#                         <td id="T_fb123_row18_col0" class="data row18 col0" >Experiment Name</td>
#                         <td id="T_fb123_row18_col1" class="data row18 col1" >reg-default-name</td>
#             </tr>
#             <tr>
#                         <th id="T_fb123_level0_row19" class="row_heading level0 row19" >19</th>
#                         <td id="T_fb123_row19_col0" class="data row19 col0" >USI</td>
#                         <td id="T_fb123_row19_col1" class="data row19 col1" >3014</td>
#             </tr>
#             <tr>
#                         <th id="T_fb123_level0_row20" class="row_heading level0 row20" >20</th>
#                         <td id="T_fb123_row20_col0" class="data row20 col0" >Imputation Type</td>
#                         <td id="T_fb123_row20_col1" class="data row20 col1" >simple</td>
#             </tr>
#             <tr>
#                         <th id="T_fb123_level0_row21" class="row_heading level0 row21" >21</th>
#                         <td id="T_fb123_row21_col0" class="data row21 col0" >Iterative Imputation Iteration</td>
#                         <td id="T_fb123_row21_col1" class="data row21 col1" >None</td>
#             </tr>
#             <tr>
#                         <th id="T_fb123_level0_row22" class="row_heading level0 row22" >22</th>
#                         <td id="T_fb123_row22_col0" class="data row22 col0" >Numeric Imputer</td>
#                         <td id="T_fb123_row22_col1" class="data row22 col1" >mean</td>
#             </tr>
#             <tr>
#                         <th id="T_fb123_level0_row23" class="row_heading level0 row23" >23</th>
#                         <td id="T_fb123_row23_col0" class="data row23 col0" >Iterative Imputation Numeric Model</td>
#                         <td id="T_fb123_row23_col1" class="data row23 col1" >None</td>
#             </tr>
#             <tr>
#                         <th id="T_fb123_level0_row24" class="row_head

# %%
compare_models(sort='RMSE')
# Out:
# <style  type="text/css" >
#     #T_18ea7_ th {
#           text-align: left;
#     }#T_18ea7_row0_col0,#T_18ea7_row1_col0,#T_18ea7_row1_col1,#T_18ea7_row1_col2,#T_18ea7_row1_col3,#T_18ea7_row1_col4,#T_18ea7_row1_col5,#T_18ea7_row1_col6,#T_18ea7_row2_col0,#T_18ea7_row2_col1,#T_18ea7_row2_col2,#T_18ea7_row2_col3,#T_18ea7_row2_col4,#T_18ea7_row2_col5,#T_18ea7_row2_col6,#T_18ea7_row3_col0,#T_18ea7_row3_col1,#T_18ea7_row3_col2,#T_18ea7_row3_col3,#T_18ea7_row3_col4,#T_18ea7_row3_col5,#T_18ea7_row3_col6,#T_18ea7_row4_col0,#T_18ea7_row4_col1,#T_18ea7_row4_col2,#T_18ea7_row4_col3,#T_18ea7_row4_col4,#T_18ea7_row4_col5,#T_18ea7_row4_col6,#T_18ea7_row5_col0,#T_18ea7_row5_col1,#T_18ea7_row5_col2,#T_18ea7_row5_col3,#T_18ea7_row5_col4,#T_18ea7_row5_col5,#T_18ea7_row5_col6,#T_18ea7_